# %%
# Tugas Python & Git
Nama: Resa Aulia Amanda
Nrp: 152024128

# %%
data_panen = {
    "lokasi1": {"padi": 1500, "jagung": 700, "kedelai": 400},
    "lokasi2": {"padi": 1200, "jagung": 900, "kedelai": 500},
    "lokasi3": {"padi": 1000, "jagung": 600, "kedelai": 450},
}
data_panen
# Out:
# {'lokasi1': {'padi': 1500, 'jagung': 700, 'kedelai': 400},
#  'lokasi2': {'padi': 1200, 'jagung': 900, 'kedelai': 500},
#  'lokasi3': {'padi': 1000, 'jagung': 600, 'kedelai': 450}}

# %%
for lokasi, hasil in data_panen.items():
    print(f"{lokasi}: padi={hasil['padi']}, jagung={hasil['jagung']}, kedelai={hasil['kedelai']}")
# Out:
# lokasi1: padi=1500, jagung=700, kedelai=400
# lokasi2: padi=1200, jagung=900, kedelai=500
# lokasi3: padi=1000, jagung=600, kedelai=450

# %%
data_panen["lokasi2"]["jagung"]
# Out:
# 900

# %%
data_panen["lokasi3"]
# Out:
# {'padi': 1000, 'jagung': 600, 'kedelai': 450}

# %%
padi_lokasi1 = data_panen["lokasi1"]["padi"]
kedelai_lokasi1 = data_panen["lokasi1"]["kedelai"]

padi_lokasi2 = data_panen["lokasi2"]["padi"]
kedelai_lokasi2 = data_panen["lokasi2"]["kedelai"]

padi_lokasi3 = data_panen["lokasi3"]["padi"]
kedelai_lokasi3 = data_panen["lokasi3"]["kedelai"]

padi_lokasi1, kedelai_lokasi1
# Out:
# (1500, 400)

# %%
for lokasi, hasil in data_panen.items():
    if hasil["padi"] > 1300 or hasil["jagung"] > 800:
        print(f"{lokasi} membutuhkan perhatian khusus.")
    else:
        print(f"{lokasi} dalam kondisi baik.")
# Out:
# lokasi1 membutuhkan perhatian khusus.
# lokasi2 membutuhkan perhatian khusus.
# lokasi3 dalam kondisi baik.

# %%
print("Perubahan ini dilakukan di branch Baru")
# Out:
# Perubahan ini dilakukan di branch Baru

# %%
print("Perubahan dari MASTER")
# Out:
# Perubahan dari MASTER
